# %% [markdown]
# # Variables

# %%
username = "John"

# %%
print(username)
# Out:
# John

# %%
userage = 20

# %%
print(userage)
# Out:
# 20

# %%
_name2 = "James"

# %%
firstName = "John" #camelCase
last_name = "Doe" #snake_case

# %% [markdown]
# ## Basic Operators

# %%
x = 5
y = 2

# %%
print (x + y) #using the addition operator
# Out:
# 7

# %%
print (x - y)
# Out:
# 3

# %%
c = (x - y)

# %%
print (c)
# Out:
# 3

# %%
d = (x * y)

# %%
print (d)
# Out:
# 10

# %%
print (x/y)
# Out:
# 2.5

# %%
print (x//y) #floor division
# Out:
# 2

# %%
print (x**2) #exponents
# Out:
# 25

# %%
print (y**3)
# Out:
# 8

# %%
print (x)
# Out:
# 5

# %%
print (y)
# Out:
# 2

# %%
print (x % y)
# Out:
# 1

# %%
m = 14

# %%
n = 3

# %%
print (m % n)
# Out:
# 2

# %%
x == y #to check for equality
# Out:
# False

# %%
x > y
# Out:
# True

# %%
a = 2

b = 2

# %%
a == 2
# Out:
# True

# %%
x >= y
# Out:
# True

# %%
x <= y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
print ( x )
# Out:
# 5

# %%
x = x + 2

# %%
print ( x )
# Out:
# 11

# %%
x += 2

# %%
print ( x )
# Out:
# 13

# %%
first_number = 10

second_number = 20

# %%
first_number, second_number = 10, 20
