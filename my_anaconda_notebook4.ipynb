# %% [markdown]
# # Slicing Strings
#
# We use Square brackets for slicing/indexing[ ]
#
# we use round brackets for functions and methods( )

# %%
name = "lovelace"

# %%
name.title()
# Out:
# 'Lovelace'

# %%
print(name)
# Out:
# lovelace

# %% [markdown]
# **start : stop : step**

# %%
name[0:4]
# Out:
# 'love'

# %%
name[1:4]
# Out:
# 'ove'

# %%
name[4:8]
# Out:
# 'lace'

# %%
name[0:4:2]
# Out:
# 'lv'

# %%
print(name)
# Out:
# lovelace

# %%
name[0:8:3]
# Out:
# 'lec'

# %%
#negative indexing
#the last character in a string has an index of -1

name[-1]
# Out:
# 'e'

# %%
name[2]
# Out:
# 'v'

# %%
name[7]
# Out:
# 'e'

# %%
 name[-3:-1]
# Out:
# 'ac'

# %%
name[0:7]
# Out:
# 'lovelac'

# %%
name[:7]
# Out:
# 'lovelac'

# %%
name[0:8]
# Out:
# 'lovelace'

# %%
name[4:8]
# Out:
# 'lace'

# %%
name[4:]
# Out:
# 'lace'

# %%
name[2:]
# Out:
# 'velace'

# %%
name[-3:]
# Out:
# 'ace'

# %%
name[5:8]
# Out:
# 'ace'

# %% [markdown]
# ## Find and Replace

# %%
greeting = "Hxllo"

# %%
cleaned_greeting = greeting.replace("x", "e")

# %%
print(cleaned_greeting)
# Out:
# Hello

# %%
first_name = "Jo hn"

# %%
first_name.replace(" ", "")
# Out:
# 'John'

# %%
greeting.find("H")
# Out:
# 0

# %%
greeting.find("l")
# Out:
# 2

# %%
name
# Out:
# 'lovelace'

# %%
first_four = name[:4]

# %%
print(first_four)
# Out:
# love

# %%
print(f"The first four letters in {name} is {first_four}")
# Out:
# The first four letters in lovelace is love
