# %% [raw]
# Data structures
# #### Lists
# #### Sets
# #### Tupules
# #### Dictionaries

# %%
#To create a list of numbers, you seperate each item in the list with a comma
#A list can take different data types not only integers

num_list = [10, 20, 30, 40, 50, 60, 70]

# %%
print(num_list)
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
type(num_list)
# Out:
# list

# %%
varying_list = [10, 3.5, "Hello", True, False]

# %%
type(varying_list)
# Out:
# list

# %%
print(varying_list)
# Out:
# [10, 3.5, 'Hello', True, False]

# %%
empty_list = []

# %%
print(num_list)
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
len(num_list)
# Out:
# 7

# %%
num_list[0]
# Out:
# 10

# %%
num_list[-1]
# Out:
# 70

# %%
num_list[6]
# Out:
# 70

# %%
# To get the first three elements

num_list[0:4]
# Out:
# [10, 20, 30, 40]

# %%
num_list[:3]
# Out:
# [10, 20, 30]

# %%
num_list[-7]
# Out:
# 10

# %%
#To get the last three elements 

num_list[-3:]
# Out:
# [50, 60, 70]

# %% [markdown]
# ## List Methods

# %%
#Remember methods use points to act on a variable

#To modify an element in a list

print(num_list)
# Out:
# [20, 4, 25, 40, 45, 60, 10]

# %%
num_list[2] = 25

# %%
print(num_list)
# Out:
# [10, 20, 25, 40, 50, 60, 70]

# %%
num_list[4] = 45

# %%
print(num_list)
# Out:
# [10, 20, 25, 40, 45, 60, 70]

# %%
#to append a new element to a list

print(empty_list)
# Out:
# []

# %%
empty_list.append(24)

# %%
print(empty_list)
# Out:
# [24]

# %%
empty_list.append(45)

# %%
print(empty_list)
# Out:
# [24, 45]

# %%
empty_list.append(30)

empty_list.append(40)

empty_list.append(15)

# %%
print(empty_list)
# Out:
# [24, 45, 30, 40, 15]

# %%
print(num_list)
# Out:
# [10, 20, 25, 40, 45, 60, 70]

# %%
num_list.append(74)

# %%
print(num_list)
# Out:
# [10, 20, 25, 40, 45, 60, 70, 74]

# %%
num_list.append("cat")

# %%
print(num_list)
# Out:
# [10, 20, 25, 40, 45, 60, 70, 74, 'cat']

# %%
#to add an element to a specific index in a list

print(num_list)
# Out:
# [10, 20, 25, 40, 45, 60, 70, 74, 'cat']

# %%
num_list.insert(2,4)

# %%
print(num_list)
# Out:
# [10, 20, 4, 25, 40, 45, 60, 70, 74, 'cat']

# %%
#to remove an element from a list, use the del keyword and then access the index of the particular element you want to remove

print(num_list)
# Out:
# [10, 20, 4, 25, 40, 45, 60, 70, 74, 'cat']

# %%
del num_list[-1]

# %%
print(num_list)
# Out:
# [10, 20, 4, 25, 40, 45, 60, 70, 74]

# %%
#another way to remove an element is using pop but pop removes the elements starting from the back

num_list.pop()
# Out:
# 74

# %%
print(num_list)
# Out:
# [10, 20, 4, 25, 40, 45, 60, 70]

# %%
popped_elemet = num_list.pop()

# %%
print(popped_elemet)
# Out:
# 70

# %%
print(empty_list)
# Out:
# [24, 45, 30, 40, 15]

# %%
empty_list.remove(30)

# %%
print(empty_list)
# Out:
# [24, 45, 40, 15]

# %%
num_list.append(10)

# %%
print(num_list)
# Out:
# [10, 20, 4, 25, 40, 45, 60, 10]

# %%
num_list.remove(10)

# %%
print(num_list)
# Out:
# [20, 4, 25, 40, 45, 60, 10]

# %%
#sorting elements in a list

print(num_list)
# Out:
# [20, 4, 25, 40, 45, 60, 10]

# %%
unordered_list = [50, 8, 3, 6, 1, 18, 13]

print(unordered_list)
# Out:
# [50, 8, 3, 6, 1, 18, 13]

# %%
unordered_list.sort()

# %%
print(unordered_list)
# Out:
# [1, 3, 6, 8, 13, 18, 50]

# %%
unordered_list.sort(reverse=True)

# %%
print(unordered_list)
# Out:
# [50, 18, 13, 8, 6, 3, 1]

# %%
unordered_list.sort(reverse=False)

# %%
print(unordered_list)
# Out:
# [1, 3, 6, 8, 13, 18, 50]

# %%
#you cant store sort in a variable, for example

ordered_list = unordered_list.sort(reverse=False)

# %%
print(ordered_list)
# Out:
# None

# %%
#But you can save the result of your sorting in a new variable using the "sorted" function

print(num_list)
# Out:
# [20, 4, 25, 40, 45, 60, 10]

# %%
ordered_list = sorted(num_list)

# %%
print(ordered_list)
# Out:
# [4, 10, 20, 25, 40, 45, 60]

# %%
ordered_list = sorted(num_list, reverse=True)

# %%
print(ordered_list)
# Out:
# [60, 45, 40, 25, 20, 10, 4]

# %%
random_list = [3, 7, 15, 8, 2, 5, 1]

# %%
random_list.reverse()

# %%
print(random_list)
# Out:
# [1, 5, 2, 8, 15, 7, 3]

# %%
#How to copy a list

copied_list = num_list.copy()
#copied_list is the new variable
the output is saved in

# %%
print(copied_list)
# Out:
# [20, 4, 25, 40, 45, 60, 10]

# %%
copied_list.insert(1, 30)

# %%
print(copied_list)
# Out:
# [20, 30, 4, 25, 40, 45, 60, 10]

# %%
copied_list[1] = 15

# %%
print(copied_list)
# Out:
# [20, 15, 4, 25, 40, 45, 60, 10]

# %%
print(num_list)
# Out:
# [20, 4, 25, 40, 45, 60, 10]

# %%
first_list = [1, 2, 3]
second_list =[4, 5, 6]

# %%
full_list = first_list + second_list

# %%
print(full_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
single_element = [10]

# %%
type(single_element)
# Out:
# list

# %%
print(num_list)
# Out:
# [20, 4, 25, 40, 45, 60, 10]

# %%
num_list.index(10)
# Out:
# 6

# %%
num_list.index(25)
# Out:
# 2

# %%
min(num_list)
# Out:
# 4

# %%
max(num_list)
# Out:
# 60

# %%
sum(num_list)
# Out:
# 204

# %%
print(num_list)
# Out:
# [20, 4, 25, 40, 45, 60, 10]

# %%
sum_of_num_list = num_list[0] + num_list[2] + num_list[4]

# %%
print(sum_of_num_list)
# Out:
# 90

# %%
print(f"The sum of the selected elemets is {sum_of_num_list}")
# Out:
# The sum of the selected elemets is 90

# %%
sum_first_three = sum(num_list[0:3])

# %%
print(f"The sum of the first three elements is {sum_first_three}")
# Out:
# The sum of the first three elements is 49
