# %% [markdown]
# # Python Data Types

# %%
#integer

int_ty = 10

# %%
type(int_ty)
# Out:
# int

# %%
#float

float_ty = 3.14

# %%
type(float_ty)
# Out:
# float

# %%
#string

text = "Hello World"
another_text = "Nneoma"

# %%
type(text)
# Out:
# str

# %%
type(another_text)
# Out:
# str

# %%
long_text = "I'm in the data science track"

print(long_text)
# Out:
# I'm in the data science track

# %%
type(long_text)
# Out:
# str

# %%
another_long_text = 'I\'m in the data science track'

print(another_long_text)
# Out:
# I'm in the data science track

# %%
#boolean

print(True)
# Out:
# True

# %%
x = 10

y = 2

# %%
check = x > y

print(check)
# Out:
# True

# %%
type(check)
# Out:
# bool

# %% [markdown]
# ## True is 1
#
# ## False is 0

# %%
True + False
# Out:
# 1

# %%
True + True
# Out:
# 2

# %%
False + False
# Out:
# 0

# %% [markdown]
# ## Type Casting

# %%
m = 7

# %%
type (m)
# Out:
# int

# %%
float_m = float(m)

# %%
print(float_m)
# Out:
# 7.0

# %%
n = 3.7

# %%
type(n)
# Out:
# float

# %%
int(n)
# Out:
# 3

# %%
b = "2"

type(b)
# Out:
# str

# %%
c = int(b)

# %%
type(c)
# Out:
# int

# %%
d = float(b)

# %%
type(d)
# Out:
# float

# %%
name = "James"

# %%
#the dot(.) is the method acting on the variable
name.upper()
# Out:
# 'JAMES'

# %%
upper_name = name.upper()

# %%
print(upper_name)
# Out:
# JAMES

# %%
name.lower()
# Out:
# 'james'

# %%
upper_name.title()
# Out:
# 'James'

# %%
first_name = "Jane"

last_name = "Williams"

age = 20

# %%
print(f"My name is {first_name.title()} {last_name.title()} and I am {age} years old")
# Out:
# My name is Jane Williams and I am 20 years old

# %%
print(text)
# Out:
# Hello World

# %%
#this is a function that works alone without the dot(.)
len(text)
# Out:
# 11

# %%
full_name = " John Doe"

# %%
len(full_name)
# Out:
# 9

# %%
full_name.strip()
# Out:
# 'John Doe'

# %%
#check on replace functions
