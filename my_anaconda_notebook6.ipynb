# %% [markdown]
# # TUPULES
# We use parenthesis

# %%
num_tupule = (10, 20, 30, 40, 50, 60)

print(num_tupule)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
type(num_tupule)
# Out:
# tuple

# %%
num_tupule = 10, 20, 30, 40, 50, 60

# %%
print(num_tupule)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
#Always remember to put your comma while creating a tupule dataset

# %%
single_element_tupule = (10,)

# %%
type(single_element_tupule)
# Out:
# tuple

# %%
len(num_tupule)
# Out:
# 6

# %%
num_tupule[0]
# Out:
# 10

# %%
num_tupule[-1]
# Out:
# 60

# %%
num_tupule[0:4]
# Out:
# (10, 20, 30, 40)

# %%
num_tupule[-3:]
# Out:
# (40, 50, 60)

# %%
print(num_tupule)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
num_tupule[2] = 25
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 num_tupule[2] = 25
#
# TypeError: 'tuple' object does not support item assignment

# %%
another_tupule =(10, 20, 20, 35, 38, 40, 40, 40)

print(another_tupule)
# Out:
# (10, 20, 20, 35, 38, 40, 40, 40)

# %%
another_tupule.count(20)
# Out:
# 2

# %%
another_tupule.count(10)
# Out:
# 1

# %%
another_tupule.count(40)
# Out:
# 3

# %%
another_tupule.index(20)
# Out:
# 1

# %%
another_tupule.index(40)
# Out:
# 5

# %%
max(num_tupule)
# Out:
# 60

# %%
print(num_tupule)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
sum_of_element = num_tupule[0] + num_tupule[2] + num_tupule[4]

# %%
print(sum_of_element)
# Out:
# 90

# %%
sum_first_three = sum(num_tupule[0:3])

# %%
print(f"The sum of the first three elements is {sum_first_three}")
# Out:
# The sum of the first three elements is 60
